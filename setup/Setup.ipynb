# %%
# %fs ls 'abfss://landing@wbrprojectv1.dfs.core.windows.net'

# %%
# %fs ls 'abfss://gizmobox@deacourseextdlwbr.dfs.core.windows.net/landing/operational_data'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS complete_project
URL 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net'
WITH (STORAGE CREDENTIAL wbr_project_v1)

# %%
# %sql
CREATE CATALOG IF NOT EXISTS complete_project
MANAGED LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS complete_project.landing
MANAGED LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net/landing';

CREATE SCHEMA IF NOT EXISTS complete_project.formatted
MANAGED LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net/formatted';

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS complete_project.landing.addresses
LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net/landing/addresses';

CREATE EXTERNAL VOLUME IF NOT EXISTS complete_project.landing.customers
LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net/landing/customers';

CREATE EXTERNAL VOLUME IF NOT EXISTS complete_project.landing.orders
LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net/landing/orders';

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS complete_project.formatted.addresses
LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net/formatted/addresses';

CREATE EXTERNAL VOLUME IF NOT EXISTS complete_project.formatted.customers
LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net/formatted/customers';

CREATE EXTERNAL VOLUME IF NOT EXISTS complete_project.formatted.orders
LOCATION 'abfss://complete-project@wbrprojectv1.dfs.core.windows.net/formatted/orders';
