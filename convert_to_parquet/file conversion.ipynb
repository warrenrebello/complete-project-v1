# %%
# %fs ls /Volumes/complete_project/landing/addresses

# %%
df_addresses = spark.read.csv("/Volumes/complete_project/landing/addresses", header=True, inferSchema=True)

# %%
display(df_addresses)

# %%
df_addresses.write.mode("overwrite").parquet("/Volumes/complete_project/formatted/addresses")

# %%
df_customers = spark.read.csv("/Volumes/complete_project/landing/addresses", header=True, inferSchema=True)

# %%
display(df_customers)

# %%
df_customers.write.mode("overwrite").parquet("/Volumes/complete_project/formatted/customers")

# %%
df_orders = spark.read.json("/Volumes/complete_project/landing/orders")
display(df_orders)

# %%
df_orders.write.mode("overwrite").parquet("/Volumes/complete_project/formatted/orders")
