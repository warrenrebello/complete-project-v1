# %%
from pyspark.sql import Row

# %%
sf_options = {
    "sfUrl": "BFYGZPW-FT73403.snowflakecomputing.com",
    "sfUser": "WARRENREBELLO",
    "sfPassword": "HomeLaptop@1981",
    "sfDatabase": "COMPLETE_PROJECT",
    "sfSchema": "RAW",
    "sfWarehouse": "COMPUTE_WH"
}

# %%
df_addresses_processed = spark.read.parquet("/Volumes/complete_project/formatted/addresses")
df_customers_processed = spark.read.parquet("/Volumes/complete_project/formatted/customers")
df_orders_processed = spark.read.parquet("/Volumes/complete_project/formatted/orders")

# %%
df_addresses_processed.write.format("snowflake").options(**sf_options).option("dbtable", "raw_addresses").mode("append").save()

# %%
display(df_customers_processed)

# %%
df_customers_processed.write.format("snowflake").options(**sf_options).option("dbtable", "raw_customers").mode("append").save()

# %%
df_orders_processed.write.format("snowflake").options(**sf_options).option("dbtable", "raw_orders").mode("append").save()
